# %% [markdown]
# <a href="https://colab.research.google.com/github/vedanshsharmavansh-droid/flyrank-ml-internship/blob/main/work/notebooks/w04_baseline_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vedanshsharmavansh-droid/flyrank-ml-internship/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %% [markdown]
# ## My Rule
#
# I rank content using search volume, CTR, and competition.
#
# Content with higher search volume and CTR gets a higher score. Lower competition also increases the score.
#
# ## Reason Codes
#
# SV_HIGH = High search volume
#
# CTR_HIGH = High click-through rate
#
# COMP_LOW = Low competition
#
# REVIEW = Manual review needed

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %% [markdown]
# ## Ranked Queue
#
# The score is calculated using search volume, CTR, and competition.
#
# After calculating the score, all content is ranked from highest score to lowest score.
#
# The ranked results are saved to baseline_action_score.csv.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %% [markdown]
# ## Top-20 Review
#
# The top-ranked pages have strong search volume, good CTR, and relatively low competition.
#
# Recommended action:
# Refresh and optimize these pages first.
#
# Confidence:
# Medium.
#
# This decision could be wrong if search trends change or the available data becomes outdated.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %% [markdown]
# ## Weak Picks and Leakage Check
#
# Some low-ranked pages may still perform well because this rule does not consider content quality or seasonal trends.
#
# No future information or product flags were used when creating the score.
#
# Therefore, data leakage has been avoided.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
